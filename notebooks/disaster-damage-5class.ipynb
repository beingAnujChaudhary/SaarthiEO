# %%
# https://www.kaggle.com/datasets/sarthaktandulje/disaster-damage-5class

import kagglehub

# Download latest version
path = kagglehub.dataset_download("sarthaktandulje/disaster-damage-5class")

print("Path to dataset files:", path)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/sarthaktandulje/disaster-damage-5class/2.archive...
# 100%|██████████| 4.68G/4.68G [00:54<00:00, 92.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/sarthaktandulje/disaster-damage-5class/versions/2
