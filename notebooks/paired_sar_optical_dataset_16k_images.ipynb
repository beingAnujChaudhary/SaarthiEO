# %%
# https://www.kaggle.com/datasets/anjaliikakde/paired-sar-optical-dataset-16k-images

import kagglehub

# Download latest version
path = kagglehub.dataset_download("anjaliikakde/paired-sar-optical-dataset-16k-images")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 3.93G/3.93G [03:15<00:00, 21.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/anjaliikakde/paired-sar-optical-dataset-16k-images/versions/1
