# %%
# https://www.kaggle.com/datasets/dhawalsrivastava2583/flood-classification-dataset

import kagglehub

# Download latest version
path = kagglehub.dataset_download("dhawalsrivastava2583/flood-classification-dataset")

print("Path to dataset files:", path)
# Out:
# ...
#   2%|▏         | 200M/11.2G [00:10<09:31, 20.6MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2520/1947834893.py in <cell line: 0>()
#       4
#       5 # Download latest version
# ----> 6 path = kagglehub.dataset_download("dhawalsrivastava2583/flood-classification-dataset")
#       7
#       8 print("Path to dataset files:", path)
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/datasets.py in dataset_download(handle, path, force_download, output_dir)
#      50     h = parse_dataset_handle(handle)
#      51     logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 52     resolved_path, _ = registry.dataset_resolver(
#      53         h,
#      54         path,
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/registry.py in __call__(self, *args, **kwargs)
#      26         for impl in reversed(self._impls):
# ...
