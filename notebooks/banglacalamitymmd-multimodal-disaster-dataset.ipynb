# %%
# https://www.kaggle.com/datasets/mukaffimoin/banglacalamitymmd-multimodal-disaster-dataset

import kagglehub

# Download latest version
path = kagglehub.dataset_download("mukaffimoin/banglacalamitymmd-multimodal-disaster-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.82G/1.82G [00:25<00:00, 76.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/mukaffimoin/banglacalamitymmd-multimodal-disaster-dataset/versions/1
