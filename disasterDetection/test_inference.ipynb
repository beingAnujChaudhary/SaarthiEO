# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

PROJECT_PATH = "/content/drive/MyDrive/SaarthiEO/disasterDetection"

os.chdir(PROJECT_PATH)

print(os.getcwd())
# Out:
# /content/drive/MyDrive/SaarthiEO/disasterDetection

# %%
# !pip install -q grad-cam

# %%
import importlib
import src.config

importlib.reload(src.config)
# Out:
# <module 'src.config' from '/content/drive/MyDrive/SaarthiEO/disasterDetection/src/config.py'>

# %%
from src.inference import predict

predict("examples/fire.jpg")
# Out:
# {'class': 'fire', 'confidence': 0.7751362323760986}
